# %% [markdown]
# # Practical 2.3 Matplotlib
# ## Aim:
# Implementation of python libraries - Matplotlib
# ### Matplotlib
# `matplotlib` is a popular plotting library for Python that allows users to create a wide range of static, animated, and interactive visualizations in a variety of formats. Here are explanations of some commonly used `matplotlib` commands:

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ### Basic Matplotlib commands
#
#
# 1. `plot()`: This command is used to plot a line or scatter plot in `matplotlib`. It takes in two arrays as arguments: the x-axis values and the y-axis values. For example, `plot(x_values, y_values)` would plot a line or scatter plot with the x-axis values given by the `x_values` array and the y-axis values given by the `y_values` array.
#
# 2. `xlabel()`: This command is used to set the label for the x-axis of the plot. For example, `xlabel('Time (s)')` would set the x-axis label to "Time (s)".
#
# 3. `ylabel()`: This command is used to set the label for the y-axis of the plot. For example, `ylabel('Temperature (C)')` would set the y-axis label to "Temperature (C)".
#
# 4. `title()`: This command is used to set the title of the plot. For example, `title('Temperature vs. Time')` would set the title of the plot to "Temperature vs. Time".
#
# 5. `show()`: This command is used to display the plot on the screen. It is usually the last command in a `matplotlib` script. For example, `plot(x_values, y_values); xlabel('x-axis'); ylabel('y-axis'); title('My Plot'); show()` would create a plot with x-axis labeled "x-axis", y-axis labeled "y-axis", and title "My Plot" and display it on the screen.

# %%
plt.plot(x,y,'r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Plotting data with matplotlib')
# plt.grid(axis='x')
plt.grid()
plt.show()

# %% [markdown]
# Creating multiplots on the same canvas
#
# `subplot()`
# This command is used to create multiple plots on the same canvas. It takes in three arguments: the number of rows, the number of columns, and the index of the plot to create. For example, `subplot(2, 1, 1)` would create a plot in the top row of a 2x1 grid, while `subplot(2, 1, 2)` would create a plot in the bottom row of the same grid.
# `grid()`
# This command is used to display a grid on the plot. For example, `grid()` would display a grid on the plot. `grid(True)` would display a grid on the plot, while `grid(False)` would remove the grid from the plot.

# %% [markdown]
# Line style
#
# The line style of a graph is the pattern of dashes and dots that is used to draw the lines in the graph. In `matplotlib`, the line style of a graph can be set using the `linestyle` parameter of the `plot()` function. Here are some examples of different line styles:
#  - Solid line: `plot(x_values, y_values, linestyle='solid')`
#  - Dashed line: `plot(x_values, y_values, linestyle='dashed')`
#  - Dotted line: `plot(x_values, y_values, linestyle='dotted')`
#  - Dash-dot line: `plot(x_values, y_values, linestyle='dashdot')`
#  - Dash-dot-dot line: `plot(x_values, y_values, linestyle='dashdotdot')`
#  - No line: `plot(x_values, y_values, linestyle='none')`
#  - Custom line style: `plot(x_values, y_values, linestyle=(0, (1, 1)))`
# You can use the short hand as follows:
#  - Solid line: `plot(x_values, y_values, '-')`
#  - Dashed line: `plot(x_values, y_values, '--')`
#  - Dotted line: `plot(x_values, y_values, ':')`
#  - Dash-dot line: `plot(x_values, y_values, '-.')`
#  - Dash-dot-dot line: `plot(x_values, y_values, '-..')`
#  - No line: `plot(x_values, y_values, 'none')`

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'r--') 
plt.subplot(1,3,2)
plt.grid(color='blue',linestyle='--', linewidth=0.5)
plt.plot(y,x,'g*--')
plt.subplot(1,3,3)
plt.plot(y,y,'m.-.');

# %%
plt.scatter(x,y);

# %% [markdown]
# There are several types of graphs that are commonly used to represent different types of data. Here are explanations of some commonly used types of graphs:
#
# 1. Scatter plot: A scatter plot is used to display the relationship between two variables. It displays data as a set of points, where each point represents a single observation. The x-axis and y-axis represent the two variables being compared. Scatter plots are useful for identifying trends and outliers in data. They are also useful for identifying relationships between variables. In matplotlib, scatter plots can be created using the `scatter()` function.
#
# 2. Bar graph: A bar graph is used to compare different categories of data. It displays data as a series of bars, where the height of each bar represents the value of the data being displayed. Bar graphs are useful for displaying discrete data and comparing data across different categories. In matplotlib, bar graphs can be created using the `bar()` function.
#
# 3. Histogram: A histogram is used to display the distribution of a single variable. It displays data as a series of bars, where each bar represents a range of values for the variable being displayed. Histograms are useful for identifying the shape of a distribution and identifying outliers. In matplotlib, histograms can be created using the `hist()` function.
#
# 4. Pie chart: A pie chart is used to display the relative proportions of different categories of data. It displays data as a circle divided into slices, where each slice represents a proportion of the data being displayed. Pie charts are useful for displaying data as a percentage of a whole and comparing proportions across different categories. In matplotlib, pie charts can be created using the `pie()` function.

# %%
plt.bar(x,y);

# %%
x = np.random.normal(120,20,350)
plt.hist(x)
plt.show()

# %%
x
# Out:
# array([126.78112108, 100.30079291, 104.93741132, 144.76115951,
#        116.42969549,  96.94304118, 116.627565  , 113.48626109,
#        122.81718826, 114.41401026, 104.34767098, 120.95396774,
#        134.46178225, 125.24998947,  92.5232089 , 122.23506816,
#        122.98749893, 125.68986601, 157.28971073,  88.92357735,
#        113.54388825, 117.06586144, 111.95372359, 106.49111658,
#        130.41985471, 133.63254879,  98.58231048, 117.25790552,
#        110.85159752, 156.15265308, 132.9898201 , 143.97363799,
#        125.86768898, 121.46634926, 101.20082825, 135.99271945,
#         91.86271896, 134.08497601,  94.12221157, 119.47979684,
#        159.06267635, 103.90507419, 114.00115671, 125.61778264,
#        142.55071658, 156.9380464 ,  95.95627652, 116.44093498,
#         55.55620759, 134.25926094, 116.41295287, 140.30698727,
#        136.03434768, 135.5847414 , 111.05991479, 134.9923902 ,
#        135.51170408, 110.04099206, 123.60441751, 134.14575546,
#        113.30975735,  99.22088773, 124.37947825, 139.6744711 ,
#        112.36054106, 117.98917089,  91.89637125, 105.29264377,
#        122.94769169,  96.62975723,  77.50391502, 115.15550535,
#         84.41011094, 148.27675427, 140.12870239, 144.20207235,
#        139.28545546, 117.75698247,  98.39991444,  88.4306823 ,
#         81.22375674, 139.97393893, 112.01295518, 118.49031647,
#        141.80748923, 123.66974068, 100.31072469, 144.49545862,
#        132.15637159,  78.78680327, 134.13427826, 100.16521817,
#        140.13835198, 107.40319202, 117.98931442, 155.69974651,
#        122.10289815, 128.82994852,  91.78810948, 104.72294657,
#        116.40169698, 108.24961565, 120.35717948, 135.54038979,
#        119.75195016, 127.62713549, 117.67871979, 104.58042678,
#        101.89886992, 124.71263484,  96.87915392, 129.44389043,
#        108.58556715, 119.46625037, 112.11463236, 168.87115127,
#        134.65565327, 107.90926222, 141.90092989, 114.68960298,
#        110.74944341, 148.93334926, 119.18880574, 110.80156542,
#        106.27930609, 103.8898959 , 105.71859836, 133.19596205,
#        140.68272482, 100.79398555, 128.12599652, 103.73396497,
#        132.13764287, 152.37303716, 143.2188494 , 132.82425191,
#        125.22946135,  97.3507924 , 144.37933735, 103.2153485 ,
#        119.0112923 , 138.05933245, 114.57008325, 131.96023718,
#        113.46481619,  96.87796483, 120.11012981,  95.47591352,
#        106.24944864, 106.3267614 , 118.49759942, 109.43065465,
#        102.52680536,  97.5013219 , 111.8442234 , 115.12673875,
#        143.08769016, 125.83282418, 124.30769344,  96.68910274,
#         87.57456413,  90.98356183,  73.25031447, 108.47893405,
#         99.1937102 , 111.84478337, 130.19932005, 107.70017516,
#        105.91734783,  82.43393001, 129.9599797 , 124.6672588 ,
#        103.18087019,  96.4834397 , 119.93972767, 165.66333983,
#        164.51757118, 142.16577786, 124.0596536 , 102.89314497,
#         86.19833213, 121.51074744, 116.86081453, 152.04487308,
#        110.21883623,  85.04022084, 161.82673241, 136.7255905 ,
#        110.40344575,  94.83365559, 118.5038506 , 130.81087015,
#        129.12121116, 118.25462494, 112.84899969, 127.54277318,
#        129.0982412 , 145.21035576, 104.46410415, 130.74342564,
#         98.35110638, 136.46161188, 115.7709094 , 133.53975307,
#        107.83430356, 117.31797972, 118.16936603,  65.62294294,
#        124.98073619, 148.50059943, 141.10351631, 112.34910001,
#        124.57925549, 117.75320017, 111.42917897, 115.84024977,
#         94.20303483, 129.71425838, 119.07862346, 136.71867865,
#        118.59606389,  99.78523373, 119.35633425, 116.42803276,
#        140.27518831, 126.49306093,  84.14987842, 126.42652194,
#        118.61382059, 127.15923482,  90.82201294,  94.06257688,
#        102.02188074, 109.62580706, 125.68040414, 110.98238842,
#         93.84049991, 124.96973671, 110.86524142, 114.55304048,
#        113.09517437, 113.9138533 , 125.05635841,  96.57682155,
#        123.24054697, 117.79765494,  89.56229306, 110.21118019,
#        155.6662344 , 143.52763556,  96.4108925 , 125.7675076 ,
#        136.92507555, 131.57700152, 126.52006004,  91.82930043,
#         82.52243579, 109.02109608, 118.96778213, 144.79476049,
#         89.96072069, 114.88766337, 127.73111913, 128.44614593,
#        125.63217536, 135.15779546, 146.28466165,  92.47728622,
#         93.36796486, 123.71321846, 131.966937  , 117.16632136,
#        113.35804585,  78.77966985,  85.67511363,  85.74132773,
#        147.1942166 , 154.58034595,  91.81264196, 138.19991408,
#        120.13409912, 107.08056998,  84.482655  , 108.11702919,
#        134.37604878, 102.63785236, 112.84412709, 145.42089995,
#        110.01184324, 107.08436007, 129.06534748, 124.90792673,
#        140.23638606,  83.48551417, 117.49322961, 102.38571694,
#        110.62569577, 153.13681201, 107.15258881, 144.04048172,
#         93.438836  ,  92.67748988,  92.72963853,  90.67756382,
#        131.24370494,  74.26880231, 142.88133657, 129.57644547,
#        137.11141983, 141.96898655, 117.00881672, 141.220126  ,
#        113.59194197, 121.18228937, 151.21313736,  99.10854591,
#        120.75935135, 130.99558326, 143.36906242, 139.02841666,
#        121.49617304, 124.69621648, 111.26345378,  89.05218148,
#        134.39369648, 151.88004286, 123.68882948,  89.30036329,
#        105.98498706, 121.23989827, 132.15432519, 130.15959961,
#        112.24206224, 110.17466006, 110.01642278, 157.66904474,
#        122.46623769, 131.62035975, 101.3765416 , 134.78584999,
#        142.67442846, 121.30869481, 100.03913973, 148.21803919,
#        126.3782762 ,  91.23322011, 120.95488389, 139.49382811,
#        109.30832562, 145.70113971])

# %%
y = np.array([35,25,25,15])
plt.pie(y);

# %%
myLabels = ['Apples','Bananas','Cherries','Dates']
plt.pie(y,labels=myLabels)
plt.show();

# %% [markdown]
# Introduction to Object Oriented Method
#
# In `matplotlib`, object-oriented programming (OOP) is an alternative approach to creating plots that provides more control and flexibility over the plot creation process.
#
# The OOP approach involves creating a Figure object, which represents the overall window or page that contains all the subplots or other graphical elements. The Figure object can contain one or more Axes objects, which represent individual plots or graphs within the figure. Axes objects are the main objects used to create and modify plots in `matplotlib`.
#
# Using the OOP approach, you can also create multiple subplots on the same Figure object, add legends, customize tick labels, and more. The OOP approach provides a more flexible and customizable way to create plots in `matplotlib`.
#
# The OOP approach in `matplotlib` also provides several other features that can be used to customize plots. Here are a few examples:
#
# 1. Creating Multiple Subplots: You can create multiple subplots on the same Figure object by creating multiple Axes objects and arranging them in a grid using the `subplots()` function. Here's an example:

# %%
x = np.linspace(0, 5, 11)
y=x**2

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'b')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('Plotting data with matplotlib')
plt.show();

# %% [markdown]
# Inset Graphs
#
# An inset graph is a small graph that is placed inside a larger graph. It is used to show a zoomed-in view of a particular region of the larger graph. In `matplotlib`, inset graphs can be created using the `inset_axes()` function.

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # main axes
axes2 = fig.add_axes([0.175,0.5,0.4,0.3]) # inset axes

# main figure
axes1.plot(x,y,'b-->')
axes1.set_xlabel('X axis')
axes1.set_ylabel('Y axis')
axes1.set_title('Main Plot')

# inset graph
axes2.plot(y,x,'r<--')
axes2.set_xlabel('X axis')
axes2.set_ylabel('Y axis')
axes2.set_title('Inset Plot');

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # main axes
axes2 = fig.add_axes([0.5,0.8,0.4,0.3]) # inset axes

# main figure
axes1.plot(x,y,'b-->')
axes1.set_xlabel('X axis')
axes1.set_ylabel('Y axis')
axes1.set_title('Main Plot')

# inset graph
axes2.plot(y,x,'r<--')
axes2.set_xlabel('X axis')
axes2.set_ylabel('Y axis')
axes2.set_title('Inset Plot');

# %%
fig, axes = plt.subplots()

axes.plot(x,y,'b*')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('Plotting data with matplotlib - subplots');

# %%
figs, axes = plt.subplots(nrows=1, ncols=4)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:
    ax.plot(x,y,'b')
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_title('subplots 2')

# Display the figure object
figs

# %%
figs.tight_layout()
figs

# %% [markdown]
# Aspect Ratio, DPI and Figure Size

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# Figure size x * dpi = width, y * dpi = height

# %%
fig, axes = plt.subplots(figsize=(4,3), dpi=100)

axes.plot(x,y,'r')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('Plotting data with matplotlib - Modifying size and DPI');

# %% [markdown]
# Saving Figures
#
# Matplotlib can generate high-quality figures in a variety of formats, including PNG, JPG, EPS, SVG, and PDF. You can save a figure using the `savefig()` function. Here's an example:
# ```python
# fig.savefig('my_plot.png')
# ```
# The `savefig()` function takes in the filename of the file to save the figure in. The file extension of the filename determines the format of the saved figure. For example, `my_plot.png` would save the figure in PNG format, while `my_plot.jpg` would save the figure in JPG format.

# %%
fig.savefig("Saving Figures in Matplotlib - Example.png", dpi=200)

# %% [markdown]
# Legends
#
# You can use the `label` argument in the `plot()` function to add a label to a line or scatter plot. For example, `plot(x_values, y_values, label='My Line')` would add the label "My Line" to the line or scatter plot.

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label="X Squared")
ax.plot(x, x**3, label="X Cubed")
ax.legend()
ax.set_title("Plotting data with matplotlib - Legend");

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x, label="X")
ax.plot(x, x**4, label="X Raised to 4")
ax.legend(loc=10)
ax.set_title("Plotting data with matplotlib - Legend");

# %% [markdown]
# How loc in legend works
#
# You can use the `legend()` function to add a legend to a plot. For example, `legend(loc='upper left')` would add a legend to the plot with the legend labels in the upper left corner of the plot. The `loc` argument can take on several different values, including `upper right`, `upper left`, `lower right`, `lower left`, `right`, `center left`, `center right`, `lower center`, `upper center`, and `center`. The default value for `loc` is `best`, which automatically chooses the best location for the legend. You can also pass number to the `loc` argument to specify the exact location of the legend. For example, `legend(loc=2)` would add a legend to the plot with the legend labels in the upper left corner of the plot.

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2, 'b.-')
ax.plot(x, x**3, 'g--');

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.5) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code
ax.set_title("Plotting data with matplotlib - Colors");

# %% [markdown]
# Line marker styles
#
# You can use the `marker` argument in the `plot()` function to change the style of the markers used in a line or scatter plot. For example, `plot(x_values, y_values, marker='o')` would plot a line or scatter plot with circular markers. The `marker` argument can take on several different values, including `o`, `s`, `^`, `*`, `+`, `x`, `D`, `d`, `h`, `H`, `p`, `v`, `<`, `>`, and `.`. The default value for `marker` is `None`, which plots a line without markers. You can also pass a tuple to the `marker` argument to specify the exact style of the markers. For example, `plot(x_values, y_values, marker=('o', 's'))` would plot a line or scatter plot with circular markers and square markers.

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="cyan", lw=1, ls='-', marker='o', markersize=5)
ax.plot(x, x+2, color="pink", lw=1, ls='-', marker='s', markersize=10)
ax.plot(x, x+3, color="grey", lw=1, ls='--', marker='^', markersize=20, markerfacecolor='white', markeredgewidth=5, markeredgecolor='pink')
ax.plot(x, x+4, color="pink", lw=1, ls='-', marker='*', markersize=10)
ax.plot(x, x+5, color="cyan", lw=1, ls='-', marker='<', markersize=5)
ax.set_title("Plotting data with matplotlib - Markers");

# %% [markdown]
# Control over axis appearance
#
# You can use the `axis()` function to control the appearance of the x-axis and y-axis. For example, `axis([0, 10, 0, 10])` would set the x-axis limits to 0 and 10 and the y-axis limits to 0 and 10. The `axis()` function can take on several different values, including `off`, `equal`, `scaled`, `tight`, `auto`, `image`, `square`, `tight`, `nor` and `scaled`. The default value for `axis` is `auto`, which automatically chooses the axis limits based on the data. You can also pass a tuple to the `axis` argument to specify the exact limits of the x-axis and y-axis. For example, `axis([0, 10, 0, 10])` would set the x-axis limits to 0 and 10 and the y-axis limits to 0 and 10.

# %% [markdown]
# Plot Range
#
# You can use the `xlim()` and `ylim()` functions to control the range of values displayed on the x-axis and y-axis. For example, `xlim(0, 10)` would set the x-axis limits to 0 and 10. The `xlim()` and `ylim()` functions can take on several different values, including `auto`, `tight`, `scaled`, `equal`, `off`, `image`, `square`, `tight`, `nor` and `scaled`. The default value for `xlim` and `ylim` is `auto`, which automatically chooses the axis limits based on the data. You can also pass a tuple to the `xlim` and `ylim` arguments to specify the exact limits of the x-axis and y-axis. For example, `xlim(0, 10)` would set the x-axis limits to 0 and 10.

# %%
fig, axes = plt.subplots(1,3, figsize=(12,4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# Box Plot
#
# You can use the `boxplot()` function to create a box plot. For example, `boxplot(x_values)` would create a box plot of the values in the list `x_values`.

# %%
data = [np.random.normal(2,std,100) for std in range(1,4)]
plt.boxplot(data, vert=True, patch_artist=True);

# %%
data
# Out:
# [array([ 0.12953703,  3.55804476,  2.32505074,  1.28468786,  2.43684153,
#          1.45532457,  1.38850644,  1.94074532,  2.84775865,  0.98101487,
#          3.0899995 ,  1.31893628,  2.51031884,  1.58027509,  1.04778417,
#          2.15642064,  0.81603719,  1.72719139,  3.26804754,  1.97741016,
#          1.28947623,  0.93174451,  3.3170643 ,  2.2358821 ,  1.24118963,
#          1.09971479,  3.94379531,  2.47035031,  4.05270683,  3.46821834,
#         -1.00024994,  1.78700585,  3.1262805 ,  2.37750281,  4.16133465,
#          2.24960534,  4.19042191,  1.14507428,  1.87511281,  3.30193698,
#          4.07668041,  2.45100127,  0.77910192,  2.24335178,  2.15970832,
#          3.25840658,  0.27593867,  2.33824111,  1.37737917,  1.48645665,
#          1.70264256,  2.38318256,  3.26238442,  1.67065223,  2.52806808,
#          1.72000003,  2.5635926 ,  1.01817446,  1.51347057,  1.70583135,
#          3.16144234,  3.29154068,  2.42768404,  3.03019844,  1.78516828,
#          2.7875108 ,  5.17506861,  2.70915339,  1.59105499,  1.32139122,
#          2.46017329,  0.59027165,  1.31732155,  1.59321312,  1.10526014,
#          2.71624969,  0.67893109,  3.05748717,  2.80289585,  3.53692009,
#          3.87939725,  3.0883814 ,  1.50272346,  2.64252942,  2.7157345 ,
#          3.9633654 ,  1.41892027,  0.76558688,  3.95629098,  2.95509494,
#          2.63466432,  0.10232071,  0.26349907, -0.44149587,  1.73095579,
#          0.74842457,  2.69119339,  2.53144922,  3.49292236,  2.27425337]),
#  array([ 0.45125764,  3.20862121,  3.61823066,  3.95525331,  1.19056464,
#          0.52473528,  2.0613558 ,  5.59010619,  2.38420352,  0.1978052 ,
#          3.16747489,  4.422336  , -1.67783245,  1.40280775,  1.40985654,
#          1.71700133, -0.04719236,  1.97802323,  1.57828827, -1.02826867,
#          3.12372387,  5.03439632,  1.23467518,  3.75737381,  2.93604203,
#          0.83448284,  0.69359806,  1.18121571,  3.37315724,  1.84580878,
#         -0.33889666,  4.5120024 ,  2.03916236,  1.47724936,  1.78728489,
#          2.39978304, -1.94765936,  2.56576734,  2.76115934,  4.63689629,
#          3.42922932,  2.13734245, -2.60576578,  4.75029374,  1.83442065,
#          0.69810981,  3.00716943,  5.421323  ,  3.83389935,  4.42683831,
#          3.36826758,  3.56468896, -0.67557835,  1.24624494,  1.20005987,
#          4.65802805,  7.51494543,  0.56207332,  2.77175072,  1.46151772,
#          3.85797556, -0.12568654,  5.52239243,  2.12388767,  3.73262328,
#          2.76746309, -0.72774509,  5.53426767,  3.50975212,  3.9984233 ,
#          0.83904595,  2.35581159,  0.18251537,  5.99008882,  1.41238464,
#          3.57671096,  0.80100828,  1.13249649,  1.65576615,  5.10402618,
#         -5.24256397,  3.19181819,  2.57220023,  0.90686614, -2.35020574,
#          3.20690395,  3.49286601,  2.20807576,  3.64536833,  2.97561097,
#          3.13267869, -0.75557346,  4.22459648,  0.47929208,  0.44311853,
#          0.38326889,  3.66260356,  1.65736376,  0.5065958 ,  3.81290118]),
#  array([-0.04782293,  1.00516712,  7.85031818,  3.60037937,  2.62936854,
#          4.48209228, -1.42847026, -3.45577962, -0.92811442,  2.40759635,
#         -1.94334089,  0.15313303, -3.78069635,  5.41019772,  0.41244733,
#          4.10051259, -6.00444515, -1.27521681,  7.78061047,  2.53053048,
#         -4.13567033,  7.2107146 , -0.22612875,  1.83193843,  2.70346847,
#         -6.59430131, -0.85842826,  3.32577769,  2.61535835,  1.57743361,
#          1.80624608, -0.80992891,  6.56366629,  0.74883728,  2.77996626,
#          6.40389155,  2.74574116,  1.12396757, -0.06919462,  2.06789142,
#          9.96540727,  4.50453579, -0.94586738,  9.18411367, -3.21515869,
#          5.72801517,  4.8085408 ,  0.85039934,  0.74653101,  4.84685751,
#          1.53016913,  3.65400107,  2.16047143,  2.77813409,  5.43425909,
#         -2.61446195,  4.12234123, -3.05186979,  0.28118163,  4.53658118,
#          2.94843802, -4.4485765 , -0.14338348,  2.80468177,  4.20418667,
#          3.85963023, -1.82844487,  4.39294077,  0.4733972 ,  0.66716618,
#          5.58996222,  4.51776386, -1.0693823 ,  1.09940884,  2.41949856,
#          1.68217706,  5.16975476, -2.42604808, -2.00490145,  6.40711475,
#          3.47893537, -1.2695704 ,  2.21283844,  2.24507983,  0.51348457,
#          3.1678635 ,  0.73522824,  2.97708226, -0.47173526,  4.58039432,
#          4.5280702 ,  5.23369169,  3.33218736,  2.75325897,  3.35008165,
#         -2.14050453,  6.80378018,  4.18008839,  3.72228848,  2.44962949])]

# %% [markdown]
# ___
#
#
# # Matplotlib Exercises
#
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercise 0
# 1. Take a dataset of your choice and plot graphs using matplotlib(convert numeric data to nominal where ever required)
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,150)
y = x*2
z = x**3

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# if not using jupyter notebook, we use plt.show() to show the plot

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,2,2]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig, ax = plt.figure()
ax.

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,2,2] and [0.4,0.5,.1,.1] respectively.**

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**
